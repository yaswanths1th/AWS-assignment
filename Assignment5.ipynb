# %%
str1 = "Hello"
str2 = "World"
concatenated_string = str1 + " " + str2
print("Concatenated string:", concatenated_string)
# Out:
# Concatenated string: Hello World

# %%
# Using the % operator
name = "jonny"
age = 25
formatted_string = "Name: %s, Age: %d" % (name, age)
print("Formatted string (using % operator):", formatted_string)
# Out:
# Formatted string (using % operator): Name: jonny, Age: 25

# %%
# Using the format() method
formatted_string = "Name: {}, Age: {}".format(name, age)
print("Formatted string (using format() method):", formatted_string)

# Using f-strings (formatted string literals)
formatted_string = f"Name: {name}, Age: {age}"
print("Formatted string (using f-strings):", formatted_string)

# Using template strings
from string import Template
template = Template("Name: $name, Age: $age")
formatted_string = template.substitute(name=name, age=age)
print("Formatted string (using template strings):", formatted_string)
# Out:
# Formatted string (using format() method): Name: jonny, Age: 25
# Formatted string (using f-strings): Name: jonny, Age: 25
# Formatted string (using template strings): Name: jonny, Age: 25

# %%
# Addition
result_add = 4 + 2
print("Addition result:", result_add)
# Out:
# Addition result: 6

# %%
# Subtraction
result_sub = 5 - 3
print("Subtraction result:", result_sub)

# Multiplication
result_mul = 5 * 4
print("Multiplication result:", result_mul)

# Division
result_div = 10 / 2
print("Division result:", result_div)

# Exponentiation
result_exp = 3 ** 4
print("Exponentiation result:", result_exp)

# Modulus
result_mod = 19 % 3
print("Modulus result:", result_mod)
# Example for -= (Subtraction assignment)
x = 10
x -= 3  # Equivalent to x = x - 3
print("After subtraction assignment:", x)

# Example for *= (Multiplication assignment)
y = 6
y *= 3  # Equivalent to y = y * 2
print("After multiplication assignment:", y)

# Example for /= (Division assignment)
z = 15
z /= 5  # Equivalent to z = z / 4
print("After division assignment:", z)
# Out:
# Subtraction result: 2
# Multiplication result: 20
# Division result: 5.0
# Exponentiation result: 81
# Modulus result: 1
# After subtraction assignment: 7
# After multiplication assignment: 18
# After division assignment: 3.0
